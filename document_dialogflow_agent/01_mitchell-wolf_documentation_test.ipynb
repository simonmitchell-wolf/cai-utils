# %%
from google.auth import default
from dfcx_scrapi.core.flows import Flows
from dfcx_scrapi.core.pages import Pages
from dfcx_scrapi.core.intents import Intents
import vertexai
from vertexai.generative_models import GenerativeModel, HarmCategory, HarmBlockThreshold
from google.cloud.dialogflowcx_v3beta1 import types
import json
import re
from google.protobuf.json_format import MessageToDict
from typing import Optional
import logging
from pathlib import Path
import yaml
import atexit

# %%
intents = Intents(agent_id="projects/ai-ml-team-sandbox/locations/us-east1/agents/fac86b77-f640-41f6-937b-22f037d6cc22")

# %%
all_intents = {}
for intent in intents.list_intents():
    all_intents[intent.display_name] = [
        "".join([part.text for part in phr.parts])
        for phr in intent.training_phrases
    ]
all_intents
# TODO: Sample 10 each

# %%
def setup_logging():
    config_file = Path("config.yaml") 
    with open(config_file) as f:
        config = yaml.safe_load(f)
    logging.config.dictConfig(config=config)
    queue_handler = logging.getHandlerByName("queue_handler")
    if queue_handler is not None:
        queue_handler.listener.start()
        atexit.register(queue_handler.listener.stop)

setup_logging()

# %%
logger = logging.getLogger("dialogflow_annotator")

class DialogflowAnnotator:

    DEFAULT_GENERATION_CONFIG = {
        "max_output_tokens": 8192,
        "temperature": 0,
        "top_p": 0.95,
    }

    DEFAULT_SAFETY_SETTINGS = {
        HarmCategory.HARM_CATEGORY_HATE_SPEECH: HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
        HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT: HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
        HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT: HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
        HarmCategory.HARM_CATEGORY_HARASSMENT: HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
    }

    SYSTEM_INSTRUCTION = "You are an expert on Google Dialogflow CX structure and describing how Dialogflow agents work."

    def __init__(
        self,
        agent_id: str,
        model: str | GenerativeModel = "gemini-1.5-flash-001",
        generation_config: Optional[dict[str, str | int | float]] = None,
        safety_settings: Optional[dict[HarmCategory, HarmBlockThreshold]] = None,
    ) -> None:
        self.agent_id = agent_id
        self.project_id = self.agent_id.split("/")[1]
        self.location = self.agent_id.split("/")[3]
        # TODO: Make creds more flexible
        self.creds = default()[0]
    
        self.flows_client = Flows(creds=self.creds, agent_id=self.agent_id)
        self.pages_client = Pages(creds=self.creds)
        self.intents_intents = Intents(creds=self.creds, agent_id=self.agent_id)
        self.flows_map = self.flows_client.get_flows_map()
        self.flow_page_map = self.flows_client.get_flow_page_map(agent_id=self.agent_id, rate_limit=0.5)
        
        if self.location == "global":
            vertexai.init(project=self.project_id, location="us-central1")
        else:
            vertexai.init(project=self.project_id, location=self.location)

        if isinstance(model, str):
            self.model = GenerativeModel(model, system_instruction=[self.SYSTEM_INSTRUCTION])
        else:
            self.model = model

        self.generation_config = generation_config or self.DEFAULT_GENERATION_CONFIG
        self.safety_settings = safety_settings or self.DEFAULT_SAFETY_SETTINGS
    
    def _generate_annotations(self, prompt):

        responses = self.model.generate_content(
            [prompt],
            generation_config=self.generation_config,
            safety_settings=self.safety_settings,
        )

        return responses.candidates[0].content.text

    def _parse_json_from_gemini_string(self, json_string: str):
        """Parses a dictionary from a JSON-like object string.

        Args:
        json_str: A string representing a JSON-like object, e.g.:
            ```json
            {
            "key1": "value1",
            "key2": "value2"
            }
            ```

        Returns:
        A dictionary representing the parsed object, or None if parsing fails.
        """

        try:
            # Remove potential leading/trailing whitespace
            json_string = json_string.strip()

            # Extract JSON content from triple backticks and "json" language specifier
            json_match = re.search(r"```json\s*(.*?)\s*```", json_string, re.DOTALL)

            if json_match:
                json_string = json_match.group(1)

            return json.loads(json_string)
        except (json.JSONDecodeError, AttributeError) as e:
            logger.error(f"Failed to parse JSON from string: {e}")
            return None

    def annotate_flows(
        self,
        flows: str | list[str],
        annotate_routes: bool = True,
        overwrite: bool = False,
    ) -> list[types.Page]:
        annotated_flows = []

        if isinstance(flows, str):
            flows = [flows]
        
        for i, flow in enumerate(flows):
            logger.info(f"Annotating flow {i+1}/{len(flows)}")
            if flow.startswith("projects") and len(flow.split("/")) == 8:
                annotated_flows.append(
                    self._annotate_flow(flow_id=flow, annotate_routes=annotate_routes, overwrite=overwrite)
                )
                continue
            annotated_flows.append(
                self._annotate_flow(flow_name=flow, annotate_routes=annotate_routes, overwrite=overwrite)
            )
        
        return annotated_flows

    def annotate_intents(
        self
    ) -> list[types.Intent]:
        pass

    def _annotate_flow(
        self,
        flow_name: Optional[str] = None,
        flow_id: Optional[str] = None,
        annotate_routes: bool = True,
        overwrite: bool = False,
    ) -> types.Page:
        
        output_schema = {
            "$schema": "http://json-schema.org/draft-07/schema#",
            "title": "Flow Description Format",
            "description": "Schema describing the response format to describe a page",
            "descriptions": {
                "type": "array",
                "description": "List of page descriptions",
                "items": {
                    "type": "object",
                    "properties": {
                        "name": {
                            "type": "string",
                            "description": "The ID of the page",
                            "example": "39575310-df14-4271-bbf5-7c9e60219391"
                        },
                        "display_name": {
                            "type": "string",
                            "description": "The display name of the page",
                            "example": "say_Welcome"
                        },
                        "description": {
                            "type": "string",
                            "description": "Your description of the page's functionality"
                        },
                        "transition_routes": {
                            "type": "array",
                            "description": "List of transition routes from this page",
                            "items": {
                                "type": "object",
                                "properties": {
                                    "name": {
                                        "type": "string",
                                        "description": "The ID of the transition route",
                                        "example": "39575310-df14-4271-bbf5-7c9e60219391"
                                    },
                                    "description": {
                                        "type": "string",
                                        "description": "Your description of the route"
                                    }
                                },
                                "required": [
                                    "name",
                                    "description"
                                ]
                            }
                        }
                    },
                    "required": [
                        "name",
                        "description",
                        "transitionRoutes"
                    ]
                }
            }
        }


        if flow_name is None and flow_id is None:
            raise ValueError("Must provide either flow_name or flow_id")
        
        flow_id = flow_id or self.flow_page_map[flow_name]["id"]
        flow_name = flow_name or self.flows_map[flow_id]

        if flow_name != self.flows_map[flow_id]:
            raise ValueError(f"Flow name {flow_name} does not match flow ID {flow_id}")
        
        logger.info(f"Annotating flow {flow_name}: {flow_id}")

        pages_to_annotate = [
            MessageToDict(p._pb, preserving_proto_field_name=True)
            for p in self.pages_client.list_pages(flow_id=flow_id)
        ]

        prompt = f"""Below is an array of Dialogflow CX pages represented as JSON data. For each page in the array:
- First, write a detailed description of each route.
- Then, use the route descriptions along with the JSON data to write a detailed description of what the page does overall. Be concise and use no more than 50 words to describe each route and 150 words to describe the page's functionality.
- When writing route descriptions, use the flow map or the page map to identify the destination page or flow of each route.
- Respond with a JSON object with no other text. DO NOT USE MARKDOWN.

## FLOW MAP
{self.flows_map}

## PAGE MAP
{ {data["id"]: name for name, data in self.flow_page_map.items()} }

## PAGES TO DESCRIBE
{pages_to_annotate}

## RESPONSE FORMAT
Use the following JSON schema to structure your response:
{output_schema}

YOUR RESPONSE:"""
        logger.info(f"Generating annotations for flow {flow_name}")
        generated_results = self._generate_annotations(prompt)
        logger.info(f"Parsing generated output for flow {flow_name}")
        parsed_generated_results = self._parse_json_from_gemini_string(generated_results)

        if parsed_generated_results is None:
            logger.warning(f"Failed to parse generated results for flow {flow_name}")
            return None

        annotated_pages = []

        for annotation in parsed_generated_results["descriptions"]:
            existing_page = [
                p for p in pages_to_annotate
                if p.get("name") == annotation["name"]
            ][0]

            updated_kwargs = self._build_updated_page(
                existing_page=existing_page,
                annotation=annotation,
                annotate_routes=annotate_routes,
                overwrite=overwrite
            )

            # TODO: Figure out why ujet payloads break the update_page call.
            try:
                annotated_page = self.pages_client.update_page(
                    page_id=annotation["name"],
                    **updated_kwargs
                )

                logging.info(f"Successfully described page {existing_page.get('display_name')}")
                annotated_pages.append(annotated_page)
            except ValueError as e:
                logging.error(f"Failed to describe page {existing_page.get('display_name')}: {e}")
        
        return annotated_pages

    def _build_updated_page(
        self,
        existing_page: dict[str, str],
        annotation: dict[str, str],
        annotate_routes: bool,
        overwrite: bool,
    ) -> dict[str, str]:
        
        updated_kwargs = {}

        logger.info(f"Updating page: {existing_page.get('display_name')}")

        if "description" in existing_page and not overwrite:
            logger.info(f". Page {existing_page.get('display_name')} already has a description")
        else:
            logger.info(f". Adding description to page {existing_page.get('display_name')}")
            updated_kwargs["description"] = annotation["description"]
        
        if not annotate_routes:
            return updated_kwargs
        
        current_routes = existing_page.get("transition_routes", [])
        described_routes = annotation.get("transition_routes", [])

        # TODO: Update by ID if lengths don't match
        if len(current_routes) != len(described_routes):
            logger.info(
                f". Skipping routes for page {existing_page.get('display_name')}. "
                "Number of original and updated routes does not match."
            )
        else:
            route_ids_to_update = [
                r["name"] for r in current_routes
                if overwrite or "description" not in r
            ]
                
            logger.info(f". Adding descriptions to {len(route_ids_to_update)} routes for page {existing_page.get('display_name')}")
            updated_kwargs["transition_routes"] = [
                r | c if r["name"] in route_ids_to_update else r
                for r, c in zip(current_routes, described_routes)
            ]
            
        return updated_kwargs

# %%
# AGENT_ID = "projects/ai-ml-team-sandbox/locations/us-east1/agents/fac86b77-f640-41f6-937b-22f037d6cc22"
AGENT_ID = "projects/missi-six-dev/locations/global/agents/8ea7a506-622d-449f-92e5-b8f3eaac4d71"

annotator = DialogflowAnnotator(agent_id=AGENT_ID)
# Out:
# 2024-06-28T16:51:50-0400 DEBUG    Checking None for explicit credentials as part of auth process...
# 2024-06-28T16:51:50-0400 DEBUG    Checking Cloud SDK credentials as part of auth process...
# 2024-06-28T16:51:50-0400 DEBUG    Making request: POST https://oauth2.googleapis.com/token
# 2024-06-28T16:51:50-0400 DEBUG    Starting new HTTPS connection (1): oauth2.googleapis.com:443
# 2024-06-28T16:51:50-0400 DEBUG    https://oauth2.googleapis.com:443 "POST /token HTTP/11" 200 None
# 2024-06-28T16:51:50-0400 DEBUG    Making request: POST https://oauth2.googleapis.com/token
# 2024-06-28T16:51:50-0400 DEBUG    Starting new HTTPS connection (1): oauth2.googleapis.com:443
# 2024-06-28T16:51:51-0400 DEBUG    https://oauth2.googleapis.com:443 "POST /token HTTP/11" 200 None
# 2024-06-28T16:51:51-0400 DEBUG    Making request: POST https://oauth2.googleapis.com/token
# 2024-06-28T16:51:51-0400 DEBUG    Starting new HTTPS connection (1): oauth2.googleapis.com:443
# 2024-06-28T16:51:51-0400 DEBUG    https://oauth2.googleapis.com:443 "POST /token HTTP/11" 200 None
# 2024-06-28T16:51:51-0400 DEBUG    Making request: POST https://oauth2.googleapis.com/token
# 2024-06-28T16:51:51-0400 DEBUG    Starting new HTTPS connection (1): oauth2.googleapis.com:443
# 2024-06-28T16:51:51-0400 DEBUG    https://oauth2.googleapis.com:443 "POST /token HTTP/11" 200 None
# 2024-06-28T16:52:56-0400 INFO     Annotating flow 1/7
# 2024-06-28T16:52:56-0400 INFO     Annotating flow Ticketing.Pricing: projects/missi-six-dev/locations/global/agents/8ea7a506-622d-449f-92e5-b8f3eaac4d71/flows/9364fd54-4414-4119-ae55-d8c071a02719
# 2024-06-28T16:52:57-0400 INFO     Generating annotations for flow {flow_name}
# 2024-06-28T16:52:57-0400 DEBUG    Making request: POST https://oauth2.googleapis.com/token
# 2024-06-28T16:52:57-0400 DEBUG    Starting new HTTPS connection (1): oauth2.googleapis.com:443
# 2024-06-28T16:52:57-0400 DEBUG    https://oauth2.googleapis.com:443 "POST /token HTTP/11" 200 None
# 2024-06-28T16:53:10-0400 INFO     Parsing generated output for flow {flow_name}
# 2024-06-28T16:53:10-0400 INFO     Updating page: check_IntendedParkCapture
# 2024-06-28T16:53:10-0400 INFO     . Adding description to page check_IntendedParkCapture
# 2024-06-28T16:53:10-0400 INFO     . Adding descriptions to 4 routes for page check_IntendedParkCapture
# 2024-06-28T16:53:12-0400 INFO     Successfully described page check_IntendedParkCapture
# 2024-06-28T16:53:12-0400 INFO     Updating page: say_TicketingLink
# 2024-06-28T16:53:12-0400 INFO     . Adding description to page say_TicketingLink
# 2024-06-28T16:53:12-0400 INFO     . Adding descriptions to 1 routes for page say_TicketingLink
# 2024-06-28T16:53:13-0400 INFO     Successfully described page say_TicketingLink
# 2024-06-28T16:53:13-0400 INFO     Updating page: say_UnknownPark
# 2024-06-28T16:53:13-0400 INFO     . Adding description to page say_UnknownPark
# 2024-06-28T16:53:13-0400 INFO     . Adding descriptions to 1 routes for page say_UnknownPark
# 2024-06-28T16:53:15-0400 INFO     Successfully described page say_UnknownPark
# 2024-06-28T16:53:15-0400 INFO     Updating page: say_NoTicketingLink
# 2024-06-28T16:53:15-0400 INFO     . Adding description to page say_NoTicketingLink
# 2024-06-28T16:53:15-0400 INFO     . Adding descriptions to 1 routes for page say_NoTicketingLink
# 2024-06-28T16:53:16-0400 INFO     Successfully described page say_NoTicketingLink
# 2024-06-28T16:53:16-0400 INFO     Updating page: check_TicketingLink
# 2024-06-28T16:53:16-0400 INFO     . Adding description to page check_TicketingLink
# 2024-06-28T16:53:16-0400 INFO     . Adding descriptions to 2 routes for page check_TicketingLink
# 2024-06-28T16:53:17-0400 INFO     Successfully described page check_TicketingLink
# 2024-06-28T16:53:17-0400 INFO     Annotating flow 2/7
# 2024-06-28T16:53:17-0400 INFO     Annotating flow FAQ: projects/missi-six-dev/locations/global/agents/8ea7a506-622d-449f-92e5-b8f3eaac4d71/flows/ae40be71-b597-4c7e-a1a3-7d98b335f7ec
# 2024-06-28T16:53:17-0400 INFO     Generating annotations for flow {flow_name}
# 2024-06-28T16:53:36-0400 INFO     Parsing generated output for flow {flow_name}
# 2024-06-28T16:53:36-0400 INFO     Updating page: say_FAQSearchGeneralError
# 2024-06-28T16:53:36-0400 INFO     . Adding description to page say_FAQSearchGeneralError
# 2024-06-28T16:53:36-0400 INFO     . Adding descriptions to 2 routes for page say_FAQSearchGeneralError
# 2024-06-28T16:53:36-0400 INFO     Successfully described page say_FAQSearchGeneralError
# 2024-06-28T16:53:36-0400 INFO     Updating page: wh_GenerativeFAQResponse
# 2024-06-28T16:53:36-0400 INFO     . Adding description to page wh_GenerativeFAQResponse
# 2024-06-28T16:53:36-0400 INFO     . Adding descriptions to 1 routes for page wh_GenerativeFAQResponse
# 2024-06-28T16:53:37-0400 INFO     Successfully described page wh_GenerativeFAQResponse
# 2024-06-28T16:53:37-0400 INFO     Updating page: check_FAQSearchResult
# 2024-06-28T16:53:37-0400 INFO     . Adding description to page check_FAQSearchResult
# 2024-06-28T16:53:37-0400 INFO     . Adding descriptions to 2 routes for page check_FAQSearchResult
# 2024-06-28T16:53:38-0400 INFO     Successfully described page check_FAQSearchResult
# 2024-06-28T16:53:38-0400 INFO     Updating page: set_ContextualizeQuery
# 2024-06-28T16:53:38-0400 INFO     . Adding description to page set_ContextualizeQuery
# 2024-06-28T16:53:38-0400 INFO     . Adding descriptions to 1 routes for page set_ContextualizeQuery
# 2024-06-28T16:53:38-0400 INFO     Successfully described page set_ContextualizeQuery
# 2024-06-28T16:53:38-0400 INFO     Updating page: check_FAQSearchErrorCount
# 2024-06-28T16:53:38-0400 INFO     . Page check_FAQSearchErrorCount already has a description
# 2024-06-28T16:53:38-0400 INFO     . Adding descriptions to 2 routes for page check_FAQSearchErrorCount
# 2024-06-28T16:53:39-0400 INFO     Successfully described page check_FAQSearchErrorCount
# 2024-06-28T16:53:39-0400 INFO     Updating page: say_FAQSearchTimeoutError
# 2024-06-28T16:53:39-0400 INFO     . Adding description to page say_FAQSearchTimeoutError
# 2024-06-28T16:53:39-0400 INFO     . Adding descriptions to 2 routes for page say_FAQSearchTimeoutError
# 2024-06-28T16:53:40-0400 INFO     Successfully described page say_FAQSearchTimeoutError
# 2024-06-28T16:53:40-0400 INFO     Updating page: goto_EndWithHumanEscalation
# 2024-06-28T16:53:40-0400 INFO     . Adding description to page goto_EndWithHumanEscalation
# 2024-06-28T16:53:40-0400 INFO     . Adding descriptions to 1 routes for page goto_EndWithHumanEscalation
# 2024-06-28T16:53:40-0400 INFO     Successfully described page goto_EndWithHumanEscalation
# 2024-06-28T16:53:40-0400 INFO     Annotating flow 3/7
# 2024-06-28T16:53:40-0400 INFO     Annotating flow Greeting: projects/missi-six-dev/locations/global/agents/8ea7a506-622d-449f-92e5-b8f3eaac4d71/flows/b645d43c-0d97-495d-8417-c060d9805a29
# 2024-06-28T16:53:40-0400 INFO     Generating annotations for flow {flow_name}
# 2024-06-28T16:53:47-0400 INFO     Parsing generated output for flow {flow_name}
# 2024-06-28T16:53:47-0400 INFO     Updating page: say_Greeting
# 2024-06-28T16:53:47-0400 INFO     . Page say_Greeting already has a description
# 2024-06-28T16:53:47-0400 INFO     . Adding descriptions to 0 routes for page say_Greeting
# 2024-06-28T16:53:47-0400 INFO     Successfully described page say_Greeting
# 2024-06-28T16:53:47-0400 INFO     Updating page: prompt_CurrentRequest
# 2024-06-28T16:53:47-0400 INFO     . Adding description to page prompt_CurrentRequest
# 2024-06-28T16:53:47-0400 INFO     . Adding descriptions to 1 routes for page prompt_CurrentRequest
# 2024-06-28T16:53:48-0400 INFO     Successfully described page prompt_CurrentRequest
# 2024-06-28T16:53:48-0400 INFO     Annotating flow 4/7
# 2024-06-28T16:53:48-0400 INFO     Annotating flow DonationRequest: projects/missi-six-dev/locations/global/agents/8ea7a506-622d-449f-92e5-b8f3eaac4d71/flows/d742402a-70a9-47b9-96ec-52aefe6d85dd
# 2024-06-28T16:53:48-0400 INFO     Generating annotations for flow {flow_name}
# 2024-06-28T16:54:00-0400 INFO     Parsing generated output for flow {flow_name}
# 2024-06-28T16:54:00-0400 INFO     Updating page: check_IntendedParkCapture
# 2024-06-28T16:54:00-0400 INFO     . Adding description to page check_IntendedParkCapture
# 2024-06-28T16:54:00-0400 INFO     . Adding descriptions to 4 routes for page check_IntendedParkCapture
# 2024-06-28T16:54:01-0400 INFO     Successfully described page check_IntendedParkCapture
# 2024-06-28T16:54:01-0400 INFO     Updating page: say_DonationRequestLink
# 2024-06-28T16:54:01-0400 INFO     . Adding description to page say_DonationRequestLink
# 2024-06-28T16:54:01-0400 INFO     . Adding descriptions to 1 routes for page say_DonationRequestLink
# 2024-06-28T16:54:01-0400 INFO     Successfully described page say_DonationRequestLink
# 2024-06-28T16:54:01-0400 INFO     Updating page: say_UnknownPark
# 2024-06-28T16:54:01-0400 INFO     . Adding description to page say_UnknownPark
# 2024-06-28T16:54:01-0400 INFO     . Adding descriptions to 1 routes for page say_UnknownPark
# 2024-06-28T16:54:07-0400 INFO     Successfully described page say_UnknownPark
# 2024-06-28T16:54:07-0400 INFO     Updating page: say_NoDonations
# 2024-06-28T16:54:07-0400 INFO     . Adding description to page say_NoDonations
# 2024-06-28T16:54:07-0400 INFO     . Adding descriptions to 1 routes for page say_NoDonations
# 2024-06-28T16:54:07-0400 INFO     Successfully described page say_NoDonations
# 2024-06-28T16:54:07-0400 INFO     Updating page: check_DonationLink
# 2024-06-28T16:54:07-0400 INFO     . Adding description to page check_DonationLink
# 2024-06-28T16:54:07-0400 INFO     . Adding descriptions to 2 routes for page check_DonationLink
# 2024-06-28T16:54:08-0400 INFO     Successfully described page check_DonationLink
# 2024-06-28T16:54:08-0400 INFO     Annotating flow 5/7
# 2024-06-28T16:54:08-0400 INFO     Annotating flow DataPrivacy: projects/missi-six-dev/locations/global/agents/8ea7a506-622d-449f-92e5-b8f3eaac4d71/flows/d92478de-4d34-4b1b-aa18-cba3ce9437b3
# 2024-06-28T16:54:08-0400 INFO     Generating annotations for flow {flow_name}
# 2024-06-28T16:54:13-0400 INFO     Parsing generated output for flow {flow_name}
# 2024-06-28T16:54:13-0400 INFO     Updating page: say_CCPALink
# 2024-06-28T16:54:13-0400 INFO     . Adding description to page say_CCPALink
# 2024-06-28T16:54:13-0400 INFO     . Adding descriptions to 1 routes for page say_CCPALink
# 2024-06-28T16:54:13-0400 INFO     Successfully described page say_CCPALink
# 2024-06-28T16:54:13-0400 INFO     Updating page: say_CCPAPhoneNumber
# 2024-06-28T16:54:13-0400 INFO     . Adding description to page say_CCPAPhoneNumber
# 2024-06-28T16:54:13-0400 INFO     . Adding descriptions to 1 routes for page say_CCPAPhoneNumber
# 2024-06-28T16:54:14-0400 INFO     Successfully described page say_CCPAPhoneNumber
# 2024-06-28T16:54:14-0400 INFO     Annotating flow 6/7
# 2024-06-28T16:54:14-0400 INFO     Annotating flow Ticketing.GroupVisit: projects/missi-six-dev/locations/global/agents/8ea7a506-622d-449f-92e5-b8f3eaac4d71/flows/ef7796f6-3861-4c9a-af1c-127176d3de0b
# 2024-06-28T16:54:15-0400 INFO     Generating annotations for flow {flow_name}
# 2024-06-28T16:55:11-0400 INFO     Parsing generated output for flow {flow_name}
# 2024-06-28T16:55:11-0400 INFO     Updating page: prompt_ConfirmGroupVisitSummary
# 2024-06-28T16:55:11-0400 INFO     . Page prompt_ConfirmGroupVisitSummary already has a description
# 2024-06-28T16:55:11-0400 INFO     . Adding descriptions to 2 routes for page prompt_ConfirmGroupVisitSummary
# 2024-06-28T16:55:12-0400 INFO     Successfully described page prompt_ConfirmGroupVisitSummary
# 2024-06-28T16:55:12-0400 INFO     Updating page: check_GroupVisitSizeInUtterance
# 2024-06-28T16:55:12-0400 INFO     . Adding description to page check_GroupVisitSizeInUtterance
# 2024-06-28T16:55:12-0400 INFO     . Adding descriptions to 2 routes for page check_GroupVisitSizeInUtterance
# 2024-06-28T16:55:13-0400 INFO     Successfully described page check_GroupVisitSizeInUtterance
# 2024-06-28T16:55:13-0400 INFO     Updating page: say_AcknowledgeWrongPark
# 2024-06-28T16:55:13-0400 INFO     . Page say_AcknowledgeWrongPark already has a description
# 2024-06-28T16:55:13-0400 INFO     . Adding descriptions to 1 routes for page say_AcknowledgeWrongPark
# 2024-06-28T16:55:15-0400 INFO     Successfully described page say_AcknowledgeWrongPark
# 2024-06-28T16:55:15-0400 INFO     Updating page: check_intendedParkName
# 2024-06-28T16:55:15-0400 INFO     . Page check_intendedParkName already has a description
# 2024-06-28T16:55:15-0400 INFO     . Adding descriptions to 1 routes for page check_intendedParkName
# 2024-06-28T16:55:15-0400 INFO     Successfully described page check_intendedParkName
# 2024-06-28T16:55:15-0400 INFO     Updating page: say_AcknowledgeGroupVisit
# 2024-06-28T16:55:15-0400 INFO     . Page say_AcknowledgeGroupVisit already has a description
# 2024-06-28T16:55:15-0400 INFO     . Adding descriptions to 0 routes for page say_AcknowledgeGroupVisit
# 2024-06-28T16:55:16-0400 INFO     Successfully described page say_AcknowledgeGroupVisit
# 2024-06-28T16:55:16-0400 INFO     Updating page: set_groupVisitDetails
# 2024-06-28T16:55:16-0400 INFO     . Page set_groupVisitDetails already has a description
# 2024-06-28T16:55:16-0400 INFO     . Adding descriptions to 0 routes for page set_groupVisitDetails
# 2024-06-28T16:55:16-0400 INFO     Successfully described page set_groupVisitDetails
# 2024-06-28T16:55:16-0400 INFO     Updating page: check_isGroupVisitAcknowledged
# 2024-06-28T16:55:16-0400 INFO     . Page check_isGroupVisitAcknowledged already has a description
# 2024-06-28T16:55:16-0400 INFO     . Adding descriptions to 0 routes for page check_isGroupVisitAcknowledged
# 2024-06-28T16:55:17-0400 INFO     Successfully described page check_isGroupVisitAcknowledged
# 2024-06-28T16:55:17-0400 INFO     Updating page: check_groupVisitTypeCaptured
# 2024-06-28T16:55:17-0400 INFO     . Page check_groupVisitTypeCaptured already has a description
# 2024-06-28T16:55:17-0400 INFO     . Adding descriptions to 0 routes for page check_groupVisitTypeCaptured
# 2024-06-28T16:55:18-0400 INFO     Successfully described page check_groupVisitTypeCaptured
# 2024-06-28T16:55:18-0400 INFO     Updating page: say_SummarizeGroupVisitDetails
# 2024-06-28T16:55:18-0400 INFO     . Page say_SummarizeGroupVisitDetails already has a description
# 2024-06-28T16:55:18-0400 INFO     . Adding descriptions to 0 routes for page say_SummarizeGroupVisitDetails
# 2024-06-28T16:55:18-0400 INFO     Successfully described page say_SummarizeGroupVisitDetails
# 2024-06-28T16:55:18-0400 INFO     Updating page: say_DirectToGroupVisitLink
# 2024-06-28T16:55:18-0400 INFO     . Page say_DirectToGroupVisitLink already has a description
# 2024-06-28T16:55:18-0400 INFO     . Adding descriptions to 0 routes for page say_DirectToGroupVisitLink
# 2024-06-28T16:55:19-0400 INFO     Successfully described page say_DirectToGroupVisitLink
# 2024-06-28T16:55:19-0400 INFO     Updating page: extract_ProvidedGroupVisitUpdate
# 2024-06-28T16:55:19-0400 INFO     . Adding description to page extract_ProvidedGroupVisitUpdate
# 2024-06-28T16:55:19-0400 INFO     . Adding descriptions to 3 routes for page extract_ProvidedGroupVisitUpdate
# 2024-06-28T16:55:19-0400 INFO     Successfully described page extract_ProvidedGroupVisitUpdate
# 2024-06-28T16:55:19-0400 INFO     Updating page: prompt_groupVisitTypeUtterance
# 2024-06-28T16:55:19-0400 INFO     . Page prompt_groupVisitTypeUtterance already has a description
# 2024-06-28T16:55:19-0400 INFO     . Adding descriptions to 0 routes for page prompt_groupVisitTypeUtterance
# 2024-06-28T16:55:26-0400 INFO     Successfully described page prompt_groupVisitTypeUtterance
# 2024-06-28T16:55:26-0400 INFO     Updating page: prompt_GroupVisitParams
# 2024-06-28T16:55:26-0400 INFO     . Page prompt_GroupVisitParams already has a description
# 2024-06-28T16:55:26-0400 INFO     . Adding descriptions to 3 routes for page prompt_GroupVisitParams
# 2024-06-28T16:55:26-0400 INFO     Successfully described page prompt_GroupVisitParams
# 2024-06-28T16:55:26-0400 INFO     Updating page: update_groupVisitDetails
# 2024-06-28T16:55:26-0400 INFO     . Page update_groupVisitDetails already has a description
# 2024-06-28T16:55:26-0400 INFO     . Adding descriptions to 1 routes for page update_groupVisitDetails
# 2024-06-28T16:55:29-0400 INFO     Successfully described page update_groupVisitDetails
# 2024-06-28T16:55:29-0400 INFO     Updating page: prompt_isGroupTaxExempt
# 2024-06-28T16:55:29-0400 INFO     . Page prompt_isGroupTaxExempt already has a description
# 2024-06-28T16:55:29-0400 INFO     . Adding descriptions to 0 routes for page prompt_isGroupTaxExempt
# 2024-06-28T16:55:29-0400 INFO     Successfully described page prompt_isGroupTaxExempt
# 2024-06-28T16:55:29-0400 INFO     Updating page: prompt_WhatsTaxExemptFollowUp
# 2024-06-28T16:55:29-0400 INFO     . Page prompt_WhatsTaxExemptFollowUp already has a description
# 2024-06-28T16:55:29-0400 INFO     . Adding descriptions to 0 routes for page prompt_WhatsTaxExemptFollowUp
# 2024-06-28T16:55:30-0400 INFO     Successfully described page prompt_WhatsTaxExemptFollowUp
# 2024-06-28T16:55:30-0400 INFO     Updating page: check_intendedParkUpdated
# 2024-06-28T16:55:30-0400 INFO     . Page check_intendedParkUpdated already has a description
# 2024-06-28T16:55:30-0400 INFO     . Adding descriptions to 0 routes for page check_intendedParkUpdated
# 2024-06-28T16:55:30-0400 INFO     Successfully described page check_intendedParkUpdated
# 2024-06-28T16:55:30-0400 INFO     Updating page: prompt_groupVisitUpdateUtterance
# 2024-06-28T16:55:30-0400 INFO     . Page prompt_groupVisitUpdateUtterance already has a description
# 2024-06-28T16:55:30-0400 INFO     . Adding descriptions to 0 routes for page prompt_groupVisitUpdateUtterance
# 2024-06-28T16:55:31-0400 INFO     Successfully described page prompt_groupVisitUpdateUtterance
# 2024-06-28T16:55:31-0400 INFO     Updating page: say_NonGroupRedirect
# 2024-06-28T16:55:31-0400 INFO     . Adding description to page say_NonGroupRedirect
# 2024-06-28T16:55:31-0400 INFO     . Adding descriptions to 1 routes for page say_NonGroupRedirect
# 2024-06-28T16:55:31-0400 INFO     Successfully described page say_NonGroupRedirect
# 2024-06-28T16:55:31-0400 INFO     Updating page: check_TaxExemptStatusNeeded
# 2024-06-28T16:55:31-0400 INFO     . Page check_TaxExemptStatusNeeded already has a description
# 2024-06-28T16:55:31-0400 INFO     . Adding descriptions to 0 routes for page check_TaxExemptStatusNeeded
# 2024-06-28T16:55:32-0400 INFO     Successfully described page check_TaxExemptStatusNeeded
# 2024-06-28T16:55:32-0400 INFO     Annotating flow 7/7
# 2024-06-28T16:55:32-0400 INFO     Annotating flow HR.Inquiries: projects/missi-six-dev/locations/global/agents/8ea7a506-622d-449f-92e5-b8f3eaac4d71/flows/f4429cc5-75a5-4851-bb09-d66f42f6423b
# 2024-06-28T16:55:32-0400 INFO     Generating annotations for flow {flow_name}

# %%
annotator.annotate_flows(flows=list(annotator.flows_map.keys())[10:])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 annotator.annotate_flows(flows=list(annotator.flows_map.keys())[10:])
#
# Cell In[28], line 108, in DialogflowAnnotator.annotate_flows(self, flows, annotate_routes, overwrite)
#     105 logger.info(f"Annotating flow {i+1}/{len(flows)}")
#     106 if flow.startswith("projects") and len(flow.split("/")) == 8:
#     107     annotated_flows.append(
# --> 108         self._annotate_flow(flow_id=flow, annotate_routes=annotate_routes, overwrite=overwrite)
#     109     )
#     110     continue
#     111 annotated_flows.append(
#     112     self._annotate_flow(flow_name=flow, annotate_routes=annotate_routes, overwrite=overwrite)
#     113 )
#
# Cell In[28], line 224, in DialogflowAnnotator._annotate_flow(self, flow_name, flow_id, annotate_routes, overwrite)
#     203         prompt = f"""Below is an array of Dialogflow CX pages represented as JSON data. For each page in the array:
#     204 - First, write a detailed description of each route.
#     205 - Then, use the route descriptions along with the JSON data to write a detailed description of what the page does overall. Be concise and use no more than 50 words to describe each route and 150 words to describe the page's functionality.
#    (...)
#     221
#     222 YOUR RESPONSE:"""
#     223         logger.info("Generating annotations for flow {flow_name}")
# --> 224         generated_results = self._generate_annotations(prompt)
#     225         logger.info("Parsing generated output for flow {flow_name}")
#     226         parsed_generated_results = self._parse_json_from_gemini_string(generated_results)
#
# Cell In[28], line 54, in DialogflowAnnotator._generate_annotations(self, prompt)
#      52 def _generate_annotations(self, prompt):
# ---> 54     responses = self.model.generate_content(
#      55         [prompt],
#      56         generation_config=self.generation_config,
#      57         safety_settings=self.safety_settings,
#      58     )
#      60     return responses.candidates[0].content.text
#
# File ~/.pyenv/versions/3.12.2/envs/cai-utils/lib/python3.12/site-packages/vertexai/generative_models/_generative_models.py:524, in _GenerativeModel.generate_content(self, contents, generation_config, safety_settings, tools, tool_config, stream)
#     516     return self._generate_content_streaming(
#     517         contents=contents,
#     518         generation_config=generation_config,
#    (...)
#     521         tool_config=tool_config,
#     522     )
#     523 else:
# --> 524     return self._generate_content(
#     525         contents=contents,
#     526         generation_config=generation_config,
#     527         safety_settings=safety_settings,
#     528         tools=tools,
#     529         tool_config=tool_config,
#     530     )
#
# File ~/.pyenv/versions/3.12.2/envs/cai-utils/lib/python3.12/site-packages/vertexai/generative_models/_generative_models.py:613, in _GenerativeModel._generate_content(self, contents, generation_config, safety_settings, tools, tool_config)
#     588 """Generates content.
#     589
#     590 Args:
#    (...)
#     604     A single GenerationResponse object
#     605 """
#     606 request = self._prepare_request(
#     607     contents=contents,
#     608     generation_config=generation_config,
#    (...)
#     611     tool_config=tool_config,
#     612 )
# --> 613 gapic_response = self._prediction_client.generate_content(request=request)
#     614 return self._parse_response(gapic_response)
#
# File ~/.pyenv/versions/3.12.2/envs/cai-utils/lib/python3.12/site-packages/google/cloud/aiplatform_v1beta1/services/prediction_service/client.py:2125, in PredictionServiceClient.generate_content(self, request, model, contents, retry, timeout, metadata)
#    2122 self._validate_universe_domain()
#    2124 # Send the request.
# -> 2125 response = rpc(
#    2126     request,
#    2127     retry=retry,
#    2128     timeout=timeout,
#    2129     metadata=metadata,
#    2130 )
#    2132 # Done; return the response.
#    2133 return response
#
# File ~/.pyenv/versions/3.12.2/envs/cai-utils/lib/python3.12/site-packages/google/api_core/gapic_v1/method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     128 if self._compression is not None:
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File ~/.pyenv/versions/3.12.2/envs/cai-utils/lib/python3.12/site-packages/google/api_core/grpc_helpers.py:76, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      73 @functools.wraps(callable_)
#      74 def error_remapped_callable(*args, **kwargs):
#      75     try:
# ---> 76         return callable_(*args, **kwargs)
#      77     except grpc.RpcError as exc:
#      78         raise exceptions.from_grpc_error(exc) from exc
#
# File ~/.pyenv/versions/3.12.2/envs/cai-utils/lib/python3.12/site-packages/grpc/_channel.py:1178, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1166 def __call__(
#    1167     self,
#    1168     request: Any,
#    (...)
#    1173     compression: Optional[grpc.Compression] = None,
#    1174 ) -> Any:
#    1175     (
#    1176         state,
#    1177         call,
# -> 1178     ) = self._blocking(
#    1179         request, timeout, metadata, credentials, wait_for_ready, compression
#    1180     )
#    1181     return _end_unary_response_blocking(state, call, False, None)
#
# File ~/.pyenv/versions/3.12.2/envs/cai-utils/lib/python3.12/site-packages/grpc/_channel.py:1162, in _UnaryUnaryMultiCallable._blocking(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1145 state.target = _common.decode(self._target)
#    1146 call = self._channel.segregated_call(
#    1147     cygrpc.PropagationConstants.GRPC_PROPAGATE_DEFAULTS,
#    1148     self._method,
#    (...)
#    1160     self._registered_call_handle,
#    1161 )
# -> 1162 event = call.next_event()
#    1163 _handle_event(event, state, self._response_deserializer)
#    1164 return state, call
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:400, in grpc._cython.cygrpc.SegregatedCall.next_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:211, in grpc._cython.cygrpc._next_call_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:205, in grpc._cython.cygrpc._next_call_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:78, in grpc._cython.cygrpc._latent_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:61, in grpc._cython.cygrpc._internal_latent_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:42, in grpc._cython.cygrpc._next()
#
# KeyboardInterrupt:
